# %%
### A crawler for DIVAR.IR using its POST API

# %%
import requests
import json
import math
from bs4 import BeautifulSoup as BS4

# %%
## Fetch City Lists and Categories\
root_URL = 'https://divar.ir/s/tehran'
root_response = requests.get(root_URL)

parsed_root_reponse = BS4(root_response.text, 'html.parser')
preload_data = parsed_root_reponse.find_all('script')

# %%
preload_indx = -1
for i , val in enumerate(preload_data):
    if len(val.contents) == 1 and 'window.__PRELOADED_STATE__' in val.string:
        preload_indx = i
        
## find the first and last { }
start = preload_data[preload_indx].string.find('{')
end = preload_data[preload_indx].string.rfind('}')

preload_js = json.loads(preload_data[preload_indx].string[start : end + 1])

# %%
def find_city(city_name):
    for state in preload_js["multiCity"]["data"]["children"]:
        for city in state["children"]:
            if city["name"] == city_name:
                return city["id"]

    return -1

def find_category(category_name):
    for category in preload_js["search"]["rootCat"]["children"]:
        if category["name"] == category_name:
            return category["slug"]

        else:
            for sub_cat in category["children"]:
                if sub_cat["name"] == category_name:
                    return sub_cat["slug"]

    return -1

# %%
list_of_city_names = ['تهران' , 'اصفهان', 'شیراز']
categorie = 'وسایل نقلیه'
query = "پژو ۲۰۶"
pages_to_load = 4

city_ids = []
for city_name in list_of_city_names:
    city_ids.append( str(find_city(city_name)) )

categorie_slug = find_category(categorie)

print(f'Search for: {query} in Cities: {list_of_city_names} and in the Category: {categorie}, retrive {pages_to_load} pages')
# Out:
# Search for: پژو ۲۰۶ in Cities: ['تهران', 'اصفهان', 'شیراز'] and in the Category: وسایل نقلیه, retrive 4 pages

# %%
## Create Payload
payload = {
    "city_ids": city_ids,
    "pagination_data":{"@type":"type.googleapis.com/post_list.PaginationData","page":0,"layer_page":0},
    "search_data":{"form_data":{"data":{"category":{"str":{"value":categorie_slug}},"sort":{"str":{"value":"sort_date"}}}}, "query" : query}
}

req_url = "https://api.divar.ir/v8/postlist/w/search"

responses = []
for i in range(1, pages_to_load + 1):

    payload["pagination_data"]["page"] = i
    payload["pagination_data"]["layer_page"] = i
    
    response = requests.post(req_url , data = json.dumps(payload))
    if response.ok:
        responses.append( response.json() )
        
print(f'You got {len(responses)} OK responses')
# Out:
# You got 4 OK responses

# %%
## Clean Up the Data
collected_data = []
adver_url = "https://divar.ir/v/"

for resp in responses:
    for widget in resp["list_widgets"]:
        if widget["widget_type"] == "POST_ROW":
            collected_data.append({
                "name"  : widget["data"]["title"],
                "url": adver_url + widget["data"]["title"].replace(' ', '-') + "/" + widget["data"]["action"]["payload"]["token"],
                "token" : widget["data"]["action"]["payload"]["token"],
                "price" : widget["data"]["middle_description_text"] if "middle_description_text" in  widget["data"].keys() else "-1",
                "city"  : widget["data"]["action"]["payload"]["web_info"]["city_persian"],
                "desc"  : widget["data"]["top_description_text"] if "top_description_text" in  widget["data"].keys() else "-1"
            })

# %%
## in collected data, search for full description in the ad page
url_head = "https://api.divar.ir/v8/posts-v2/web/"

for i , data in enumerate(collected_data):
    token = data["token"]
    response = requests.get(url_head + token)

    if response.ok:
        colected = response.json()
        description = colected["seo"]["description"]
        collected_data[i]["full_desc"] = description

# %%
## convert prices to intigers
def convert_str_to_int(string):
    if string == "-1":
        return -1
    number = string[:-6]
    number = number.replace(',' , '')
    return int(number)

# %%
for i , data in enumerate(collected_data):
    collected_data[i]["price"] = convert_str_to_int(data["price"])

# %%
for data in collected_data:
    print("name:" , '\t' , data["name"])
    print("url:" , '\t' ,  data["url"])
    print("token:" , '\t' , data["token"])
    print("price:" , '\t' , data["price"])
    print("city:" , '\t' , data["city"])
    print("desc:" , '\t' , data["desc"])
    print('___________________________________________________________________________________________\n')
# Out:
# name: 	 پژو 206 SD V8، مدل ۱۳۹۰
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۹۰/gZgyez1b
# token: 	 gZgyez1b
# price: 	 335000000
# city: 	 تهران
# desc: 	 ۲۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۶، اتومات مدل ۸۷
# url: 	 https://divar.ir/v/پژو-206-تیپ-۶،-اتومات-مدل-۸۷/gZheRzZq
# token: 	 gZheRzZq
# price: 	 320000000
# city: 	 تهران
# desc: 	 ۱۶۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۸/gZgqsAEz
# token: 	 gZgqsAEz
# price: 	 455000000
# city: 	 تهران
# desc: 	 ۴۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 اجاره خودرو۲۰۶پژو/اجاره کرایه ۲۰۷ ال ۹۰ پرشیا رانا
# url: 	 https://divar.ir/v/اجاره-خودرو۲۰۶پژو/اجاره-کرایه-۲۰۷-ال-۹۰-پرشیا-رانا/gZd-pVUQ
# token: 	 gZd-pVUQ
# price: 	 800000
# city: 	 تهران
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۶
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۶/gZgmblKq
# token: 	 gZgmblKq
# price: 	 425000000
# city: 	 تهران
# desc: 	 ۶۲,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۳، مدل ۱۳۸۳
# url: 	 https://divar.ir/v/پژو-206-تیپ-۳،-مدل-۱۳۸۳/gZhehVpV
# token: 	 gZhehVpV
# price: 	 150000000
# city: 	 تهران
# desc: 	 ۳۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 روکش صندلی ضخیم (اصلی)
# url: 	 https://divar.ir/v/روکش-صندلی-ضخیم-(اصلی)/wYrR10q_
# token: 	 wYrR10q_
# price: 	 380000
# city: 	 تهران
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۴۰۰
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۴۰۰/gZhaRj1E
# token: 	 gZhaRj1E
# price: 	 540000000
# city: 	 تهران
# desc: 	 ۳۵,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۹/gZhah7Gf
# token: 	 gZhah7Gf
# price: 	 260000000
# city: 	 تهران
# desc: 	 ۲۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۳
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۳/gZhaRKL6
# token: 	 gZhaRKL6
# price: 	 195000000
# city: 	 تهران
# desc: 	 ۳۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل آخر ۸۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-آخر-۸۸/gZXi5CCU
# token: 	 gZXi5CCU
# price: 	 310000000
# city: 	 تهران
# desc: 	 ۱۵۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۵
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۵/gZMKdAzI
# token: 	 gZMKdAzI
# price: 	 245000000
# city: 	 تهران
# desc: 	 ۲۳۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۵
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۵/gZIWumYf
# token: 	 gZIWumYf
# price: 	 385000000
# city: 	 شیراز
# desc: 	 ۲۶۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۸/gZgeegxa
# token: 	 gZgeegxa
# price: 	 528000000
# city: 	 تهران
# desc: 	 ۱۳۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۴
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۴/gZhaBVLK
# token: 	 gZhaBVLK
# price: 	 308000000
# city: 	 تهران
# desc: 	 ۲۲۵,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸
�۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 ۲۰۶ تیپ ۲ مدل ۹۹ بدون رنگ مشابه صفر
# url: 	 https://divar.ir/v/۲۰۶-تیپ-۲-مدل-۹۹-بدون-رنگ-مشابه-صفر/gZXeVlTn
# token: 	 gZXeVlTn
# price: 	 480000000
# city: 	 تهران
# desc: 	 ۸۱,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ 2، مدل ۱۳۹۶ با لوازم جانبی
# url: 	 https://divar.ir/v/پژو-206-تیپ-2،-مدل-۱۳۹۶-با-لوازم-جانبی/gZJGCzcv
# token: 	 gZJGCzcv
# price: 	 450000000
# city: 	 اصفهان
# desc: 	 ۱۲۸,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۸/gZeibSim
# token: 	 gZeibSim
# price: 	 295000000
# city: 	 تهران
# desc: 	 ۲۹۹,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۸/gZhGRAqU
# token: 	 gZhGRAqU
# price: 	 405000000
# city: 	 شیراز
# desc: 	 ۱۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۴
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۴/gZhGRhoc
# token: 	 gZhGRhoc
# price: 	 248000000
# city: 	 تهران
# desc: 	 ۱۶۸,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۶ اتومات، مدل ۱۳۸۷
# url: 	 https://divar.ir/v/پژو-206-تیپ-۶-اتومات،-مدل-۱۳۸۷/gZfmLZCG
# token: 	 gZfmLZCG
# price: 	 265000000
# city: 	 تهران
# desc: 	 ۲۴۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 اجاره پژو ۲۰۶ خاکستری/رنت خودرو/کرایه ماشین
# url: 	 https://divar.ir/v/اجاره-پژو-۲۰۶-خاکستری/رنت-خودرو/کرایه-ماشین/gZJiybuj
# token: 	 gZJiybuj
# price: 	 -1
# city: 	 تهران
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۶، مدل ۱۳۸۵ اتومات
# url: 	 https://divar.ir/v/پژو-206-تیپ-۶،-مدل-۱۳۸۵-اتومات/gZhChecL
# token: 	 gZhChecL
# price: 	 365000000
# city: 	 تهران
# desc: 	 ۲۶۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 مدل ۱۳۸۴ تیپ ۲ فرانسه (استهبان)
# url: 	 https://divar.ir/v/پژو-206-مدل-۱۳۸۴-تیپ-۲-فرانسه-(استهبان)/gZhCh3up
# token: 	 gZhCh3up
# price: 	 249000000
# city: 	 شیراز
# desc: 	 ۱۹۳,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۷
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۷/gZhCRmmv
# token: 	 gZhCRmmv
# price: 	 280000000
# city: 	 تهران
# desc: 	 ۲۸۵,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۶
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۶/gZhChWwZ
# token: 	 gZhChWwZ
# price: 	 425000000
# city: 	 شیراز
# desc: 	 ۱۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو ۲۰۶ اتومات ،مدل ۸۸ اقساط اقساطی
# url: 	 https://divar.ir/v/پژو-۲۰۶-اتومات-،مدل-۸۸-اقساط-اقساطی/gZhCBNRi
# token: 	 gZhCBNRi
# price: 	 395000000
# city: 	 تهران
# desc: 	 ۱۷۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 اقساط دزدگیر روکش مانیتور ماشین
# url: 	 https://divar.ir/v/اقساط-دزدگیر-روکش-مانیتور-ماشین/gZg-XoWn
# token: 	 gZg-XoWn
# price: 	 2000000
# city: 	 شیراز
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۶
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۶/gZReDv9D
# token: 	 gZReDv9D
# price: 	 400000000
# city: 	 تهران
# desc: 	 ۱۰۵,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۶ تمیز و خانگی
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۶-تمیز-و-خانگی/gZfq3lyq
# token: 	 gZfq3lyq
# price: 	 484000000
# city: 	 تهران
# desc: 	 ۷۵,۵۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 مانیتور پراید پژو ماشین پارس
# url: 	 https://divar.ir/v/مانیتور-پراید-پژو-ماشین-پارس/gZgibSjR
# token: 	 gZgibSjR
# price: 	 -1
# city: 	 شیراز
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۲
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۲/gZh-gnV9
# token: 	 gZh-gnV9
# price: 	 180000000
# city: 	 تهران
# desc: 	 ۳۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۹/gZh-wHsX
# token: 	 gZh-wHsX
# price: 	 480000000
# city: 	 اصفهان
# desc: 	 ۹۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 206 مدل85
# url: 	 https://divar.ir/v/206-مدل85/gZh6A2Ag
# token: 	 gZh6A2Ag
# price: 	 230000000
# city: 	 اصفهان
# desc: 	 ۳۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 اجاره خودرو ۲۰۶/رنت ماشین پژو ۲۰۶کرایه ای
# url: 	 https://divar.ir/v/اجاره-خودرو-۲۰۶/رنت-ماشین-پژو-۲۰۶کرایه-ای/gZNRJvSo
# token: 	 gZNRJvSo
# price: 	 700000
# city: 	 تهران
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۴
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۴/gZh2Q_iA
# token: 	 gZh2Q_iA
# price: 	 375000000
# city: 	 تهران
# desc: 	 ۱۹۱,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، مدل ۱۳۸۸
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۸۸/gZG64qEG
# token: 	 gZG64qEG
# price: 	 348000000
# city: 	 اصفهان
# desc: 	 ۲۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲اسپرت مدل ۱۳۸۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲اسپرت-مدل-۱۳۸۹/gZh6gZg4
# token: 	 gZh6gZg4
# price: 	 295000000
# city: 	 تهران
# desc: 	 ۳۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۶ خونگی رنگ فابریک صدرا
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۶-خونگی-رنگ-فابریک-صدرا/gZpFk8oK
# token: 	 gZpFk8oK
# price: 	 397000000
# city: 	 شیراز
# desc: 	 ۱۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۷
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۷/gZh6wZbU
# token: 	 gZh6wZbU
# price: 	 250000000
# city: 	 تهران
# desc: 	 ۱۳۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، مدل ۱۳۹۲ معاوضه پراید ۱۳۹۰ ۱۳۹۱
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۹۲-معاوضه-پراید-۱۳۹۰-۱۳۹۱/gZh2Ay70
# token: 	 gZh2Ay70
# price: 	 410000000
# city: 	 تهران
# desc: 	 ۱۴۸,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 اجاره پژو ۲۰۶ سفید/خودرو اجاره کرایه رنت
# url: 	 https://divar.ir/v/اجاره-پژو-۲۰۶-سفید/خودرو-اجاره-کرایه-رنت/gZOKnyQ7
# token: 	 gZOKnyQ7
# price: 	 -1
# city: 	 تهران
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۷
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۷/gZO6VUqW
# token: 	 gZO6VUqW
# price: 	 475000000
# city: 	 تهران
# desc: 	 ۱۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۸/gZh2w15K
# token: 	 gZh2w15K
# price: 	 260000000
# city: 	 تهران
# desc: 	 ۲۴۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۹/gZh2Q0M9
# token: 	 gZh2Q0M9
# price: 	 495000000
# city: 	 تهران
# desc: 	 ۷۸,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲ مدل ۱۳۸۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲-مدل-۱۳۸۹/gZh2ggzN
# token: 	 gZh2ggzN
# price: 	 290000000
# city: 	 تهران
# desc: 	 ۲۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 فنزلنزو 206سایز 30 مناسب پژو 405و 206
# url: 	 https://divar.ir/v/فنزلنزو-206سایز-30-مناسب-پژو-405و-206/gZh2AoNI
# token: 	 gZh2AoNI
# price: 	 800000
# city: 	 شیراز
# desc: 	 -1
# ___________________________________________________________________________________________
#
# name: 	 پژو ۲۰۶ تیپ ۲
# url: 	 https://divar.ir/v/پژو-۲۰۶-تیپ-۲/gZhuAqVD
# token: 	 gZhuAqVD
# price: 	 500000000
# city: 	 تهران
# desc: 	 ۴۸,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۱
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۱/gZW-WLgL
# token: 	 gZW-WLgL
# price: 	 207000000
# city: 	 تهران
# desc: 	 ۲۳۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۴
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۴/gZh2wGEv
# token: 	 gZh2wGEv
# price: 	 11111111
# city: 	 تهران
# desc: 	 ۱۷۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 SD V8، مدل ۱۳۹۴
# url: 	 https://divar.ir/v/پژو-206-SD-V8،-مدل-۱۳۹۴/gZfOdNbh
# token: 	 gZfOdNbh
# price: 	 435000000
# city: 	 شیراز
# desc: 	 ۲۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۸
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۸/gZh2AA7B
# token: 	 gZh2AA7B
# price: 	 440000000
# city: 	 تهران
# desc: 	 ۷۰,۸۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۸۳
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۸۳/gZhyQoje
# token: 	 gZhyQoje
# price: 	 217000000
# city: 	 تهران
# desc: 	 ۳۱۷,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۹۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۹۹/gZhyAc3x
# token: 	 gZhyAc3x
# price: 	 470000000
# city: 	 اصفهان
# desc: 	 ۸۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۸۲
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۸۲/gZf-3CLf
# token: 	 gZf-3CLf
# price: 	 205000000
# city: 	 تهران
# desc: 	 ۳۰۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل آخر ۱۳۹۶
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-آخر-۱۳۹۶/gZhygA6T
# token: 	 gZhygA6T
# price: 	 460000000
# city: 	 تهران
# desc: 	 ۹۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۶، مدل ۱۳۸۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۶،-مدل-۱۳۸۹/gZhygXuK
# token: 	 gZhygXuK
# price: 	 430000000
# city: 	 تهران
# desc: 	 ۲۱۹,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۲
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۲/gZhyAPf9
# token: 	 gZhyAPf9
# price: 	 165000000
# city: 	 تهران
# desc: 	 ۳۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵، مدل ۱۳۹۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵،-مدل-۱۳۹۹/gZhyAO07
# token: 	 gZhyAO07
# price: 	 537000000
# city: 	 اصفهان
# desc: 	 ۹۹,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو tu5 آریان دوگانه سوز دولکه رنگ
# url: 	 https://divar.ir/v/پژو-tu5-آریان-دوگانه-سوز-دولکه-رنگ/gZdywbHO
# token: 	 gZdywbHO
# price: 	 273000000
# city: 	 تهران
# desc: 	 ۴۸۶,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۵ مدل 1396
# url: 	 https://divar.ir/v/پژو-206-تیپ-۵-مدل-1396/gZZagX4n
# token: 	 gZZagX4n
# price: 	 469000000
# city: 	 تهران
# desc: 	 ۱۱۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۹
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۹/gZhuQvIT
# token: 	 gZhuQvIT
# price: 	 273000000
# city: 	 تهران
# desc: 	 ۴۵۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
#
# name: 	 پژو 206 تیپ ۲، مدل ۱۳۸۶ فرانسه
# url: 	 https://divar.ir/v/پژو-206-تیپ-۲،-مدل-۱۳۸۶-فرانسه/gZhuAnUq
# token: 	 gZhuAnUq
# price: 	 250000000
# city: 	 تهران
# desc: 	 ۳۶۰,۰۰۰ کیلومتر
# ___________________________________________________________________________________________
